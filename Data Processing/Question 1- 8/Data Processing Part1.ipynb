# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Importing Data Libraries

# %% [markdown]
# ## Question 1,2,3

# %%
intern=pd.read_excel('/Users/Asus/Documents/InternCsv/actual_july/Dispatch_July_2020.xlsx')

# %%
intern.shape
# Out:
# (48, 100)

# %%
intern.describe()
# Out:
#        Actual System Dispatch  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# count                      47          48          48          48          48
# unique                     46          23          22          23          23
# top                      Time           0           0           0           0
# freq                        2          23          23          23          23
#
#         Unnamed: 5  Unnamed: 6  Unnamed: 7  2020-07-01 00:00:00  Unnamed: 9  \
# count           48          48          48                   48          48
# unique          22          23          20                   21          19
# top              0           0           0                    0           0
# freq            23          23          24                   24          25
#
#         ...  Unnamed: 90  Unnamed: 91  Unnamed: 92  Unnamed: 93  Unnamed: 94  \
# count   ...           48           48           48           48           48
# ...

# %% [markdown]
# ## Question 4

# %%
# import necessary libraries
import pandas as pd
import os
import glob
  
  
# use glob to get all the csv files 
# in the folder
path = os.getcwd()
csv_files = glob.glob(os.path.join('/Users/Asus/Documents/InternCsv/forcast_july', "*.xls"))
  
  
# loop over the list of csv files
for f in csv_files:
      
    # read the csv file
    df = pd.read_excel(f)
      
    # print the location and filename
    print('Location:', f)
    print('File Name:', f.split("\\")[-1])
      
    # print the content
    print('Content:')
    #display(df) Using display, can represent the content resides in it
    print()
# Out:
# Location: /Users/Asus/Documents/InternCsv/forcast_july\july10.xls
# File Name: july10.xls
# Content:
#
# Location: /Users/Asus/Documents/InternCsv/forcast_july\july11.xls
# File Name: july11.xls
# Content:
#
# Location: /Users/Asus/Documents/InternCsv/forcast_july\july12.xls
# File Name: july12.xls
# Content:
#
# Location: /Users/Asus/Documents/InternCsv/forcast_july\july13.xls
# File Name: july13.xls
# Content:
#
# Location: /Users/Asus/Documents/InternCsv/forcast_july\july14.xls
# File Name: july14.xls
# Content:
#
# Location: /Users/Asus/Documents/InternCsv/forcast_july\july15.xls
# File Name: july15.xls
# Content:
#
# Location: /Users/Asus/Documents/InternCsv/forcast_july\july16.xls
# File Name: july16.xls
# Content:
#
# Location: /Users/Asus/Documents/InternCsv/forcast_july\july17.xls
# File Name: july17.xls
# Content:
#
# Location: /Users/Asus/Documents/InternCsv/forcast_july\july18.xls
# File Name: july18.xls
# Content:
#
# ...

# %% [markdown]
# ## Question 5

# %%
# Find out your current working directory
path =r'/Users/Asus/Documents/InternCsv/forcast_july' # use your path 
allFiles = glob.glob(path + "/*.xls") 
frame = pd.DataFrame() 
list_ = [] 
for file_ in allFiles: 
    df = pd.read_excel(file_,index_col=None, header=0) 
    list_.append(df) 
    print(file_)
frame = pd.concat(list_)
# Out:
# /Users/Asus/Documents/InternCsv/forcast_july\july10.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july11.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july12.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july13.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july14.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july15.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july16.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july17.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july18.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july19.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july20.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july21.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july22.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july23.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july24.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july25.xls
# /Users/Asus/Documents/InternCsv/forcast_july\july26.xls
# ...

# %% [markdown]
# ## Question 6

# %%
import re
pattern = re.compile("july1*")

path = os.getcwd()
csv_files = glob.glob(os.path.join('/Users/Asus/Documents/InternCsv/forcast_july', "*.xls"))

for i,line in enumerate(csv_files):
    for match in re.finditer(pattern, line):
        print ('Found on line %s: %s' ,i+1, match.group())
# Out:
# Found on line %s: %s 1 july
# Found on line %s: %s 1 july1
# Found on line %s: %s 2 july
# Found on line %s: %s 2 july11
# Found on line %s: %s 3 july
# Found on line %s: %s 3 july1
# Found on line %s: %s 4 july
# Found on line %s: %s 4 july1
# Found on line %s: %s 5 july
# Found on line %s: %s 5 july1
# Found on line %s: %s 6 july
# Found on line %s: %s 6 july1
# Found on line %s: %s 7 july
# Found on line %s: %s 7 july1
# Found on line %s: %s 8 july
# Found on line %s: %s 8 july1
# Found on line %s: %s 9 july
# Found on line %s: %s 9 july1
# Found on line %s: %s 10 july
# Found on line %s: %s 10 july1
# Found on line %s: %s 11 july
# Found on line %s: %s 11 july
# Found on line %s: %s 12 july
# Found on line %s: %s 12 july
# Found on line %s: %s 13 july
# Found on line %s: %s 13 july
# Found on line %s: %s 14 july
# Found on line %s: %s 14 july
# Found on line %s: %s 15 july
# Found on line %s: %s 15 july
# Found on line %s: %s 16 july
# Found on line %s: %s 16 july
# ...
